# %%
import numpy as np

# %%
class SGD:
    def __init__(Self, lr = 0.01):
        self.lr = lr
    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %%
network = TwoLayerNet(...)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e6a21cd14684> in <module>()
# ----> 1 network = TwoLayerNet(...)
#
# NameError: name 'TwoLayerNet' is not defined

# %%
# momentum
class Momentum:
    def __init__(self, lr=0.01, momentum = 0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None
        
    def update(self, params, grads):
        if self.v is None:
            self.v = {}
            for key, val in params.items():
                self.v[key] = np.zeros_like(val)
                
            for key in params.keys():
                self.v[key] = self.momentum*self.v[key] - self.lr*grads[key]
                params[key] += self.v[key]

# %%
#Adagrad
class AdaGrad:
    def __init__(self, lr= 0.01):
        self.lr = lr
        self.h = None
        
    def update(self, params, grads):
        if self.h is None:
            self.h={}
        for key, val in params.items():
            self.h[key] = np.zeros_like(val)
            
        for key in params.key():
            self.h[key] += grads[key] * grads[key]
            params[key] -= sel.lr * grads[key] / (np.sqrt(self.h[key]) + 1e-7)

# %%
#Adam
import numpy as np
class Adam:

    """Adam (http://arxiv.org/abs/1412.6980v8)"""

    def __init__(self, lr=0.001, beta1=0.9, beta2=0.999):
        self.lr = lr
        self.beta1 = beta1
        self.beta2 = beta2
        self.iter = 0
        self.m = None
        self.v = None
        
    def update(self, params, grads):
        if self.m is None:
            self.m, self.v = {}, {}
            for key, val in params.items():
                self.m[key] = np.zeros_like(val)
                self.v[key] = np.zeros_like(val)
        
        self.iter += 1
        lr_t  = self.lr * np.sqrt(1.0 - self.beta2**self.iter) / (1.0 - self.beta1**self.iter)         
        
        for key in params.keys():
            #self.m[key] = self.beta1*self.m[key] + (1-self.beta1)*grads[key]
            #self.v[key] = self.beta2*self.v[key] + (1-self.beta2)*(grads[key]**2)
            self.m[key] += (1 - self.beta1) * (grads[key] - self.m[key])
            self.v[key] += (1 - self.beta2) * (grads[key]**2 - self.v[key])
            
            params[key] -= lr_t * self.m[key] / (np.sqrt(self.v[key]) + 1e-7)
            
            #unbias_m += (1 - self.beta1) * (grads[key] - self.m[key]) # correct bias
            #unbisa_b += (1 - self.beta2) * (grads[key]*grads[key] - self.v[key]) # correct bias
            #params[key] += self.lr * unbias_m / (np.sqrt(unbisa_b) + 1e-7)

# %%
import sys, os
sys.path.append("/Users/jungwookim/Deep Learning From Scratch/deep-learning-from-scratch-master/")
import numpy as np
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import *


# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
optimizers = {}
optimizers['SGD'] = SGD()
optimizers['Momentum'] = Momentum()
optimizers['AdaGrad'] = AdaGrad()
optimizers['Adam'] = Adam()
#optimizers['RMSprop'] = RMSprop()

networks = {}
train_loss = {}
for key in optimizers.keys():
    networks[key] = MultiLayerNet(
        input_size=784, hidden_size_list=[100, 100, 100, 100],
        output_size=10)
    train_loss[key] = []    


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in optimizers.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizers[key].update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print( "===========" + "iteration:" + str(i) + "===========")
        for key in optimizers.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {"SGD": "o", "Momentum": "x", "AdaGrad": "s", "Adam": "D"}
x = np.arange(max_iterations)
for key in optimizers.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# SGD:2.450328057141829
# Momentum:2.293528017402902
# AdaGrad:2.2189060309520245
# Adam:2.2283242644288777
# ===========iteration:100===========
# SGD:1.826865672943966
# Momentum:0.4827881306782627
# AdaGrad:0.18983832580445867
# Adam:0.3733594917644928
# ===========iteration:200===========
# SGD:0.8335223843322914
# Momentum:0.22190812461692244
# AdaGrad:0.06782981638259389
# Adam:0.16495770086492612
# ===========iteration:300===========
# SGD:0.677492239838877
# Momentum:0.3079586920371985
# AdaGrad:0.11167959520056343
# Adam:0.2026815209477592
# ===========iteration:400===========
# SGD:0.45656918107626465
# Momentum:0.1538191648470456
# AdaGrad:0.06204210028369759
# Adam:0.12999402230096352
# ===========iteration:500===========
# SGD:0.36500983297991274
# Momentum:0.17030463197767215
# AdaGrad:0.06337438520054395
# Adam:0.11407923998103003
# ===========iteration:600===========
# SGD:0.30782697019188504
# Momentum:0.10745044833179808
# AdaGrad:0.043357344449687654
# Adam:0.08731956708872951
# ===========iteration:700===========
# SGD:0.3571734556138555
# Momentum:0.1558202129355239
# AdaGrad:0.08279822358855199
# Adam:0.11516301535624751
# ===========iteration:800===========
# SGD:0.39580982596968495
# Momentum:0.08892765211929382
# AdaGrad:0.040391318846922555
# Adam:0.051154862976147616
# ===========iteration:900===========
# SGD:0.29681690621263457
# Momentum:0.08674212074989285
# AdaGrad:0.037501641064653576
# Adam:0.03745867649309657
# ===========iteration:1000===========
# SGD:0.36324432665365636
# Momentum:0.17190297489622328
# AdaGrad:0.0783889320086103
# Adam:0.10814284248644879
# ===========iteration:1100===========
# SGD:0.20273146880933124
# Momentum:0.0657284173345021
# AdaGrad:0.024331271397986062
# Adam:0.060871993185062916
# ===========iteration:1200===========
# SGD:0.24195497129922336
# Momentum:0.08122788916737692
# AdaGrad:0.03602124128026657
# Adam:0.07147332325070882
# ===========iteration:1300===========
# SGD:0.3020914576413818
# Momentum:0.19357790344681855
# AdaGrad:0.1003334688304866
# Adam:0.15226495746041305
# ===========iteration:1400===========
# SGD:0.24247229781799207
# Momentum:0.05652322163292542
# AdaGrad:0.023082508870784953
# Adam:0.025310856877555986
# ===========iteration:1500===========
# SGD:0.14149440222090442
# Momentum:0.046905883139359034
# AdaGrad:0.018855694652625637
# Adam:0.023147181535791136
# ===========iteration:1600===========
# SGD:0.20787532132898157
# Momentum:0.06312447647651583
# AdaGrad:0.021142169447244532
# Adam:0.07743371395140691
# ===========iteration:1700===========
# SGD:0.2258274424557341
# Momentum:0.055552100907883685
# AdaGrad:0.01565673724810282
# Adam:0.028182712748386362
# ===========iteration:1800===========
# SGD:0.17120144626942324
# Momentum:0.08528188404073186
# AdaGrad:0.02468922778152793
# Adam:0.039489182497559505
# ===========iteration:1900===========
# SGD:0.2932772387229452
# Momentum:0.14321176107527223
# AdaGrad:0.020836623202704865
# Adam:0.059795396665493966

# %%
#hidden layer activate value location
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 +np.exp(-x))

x = np.random.randn(1000, 100)
node_num = 100
hidden_layer_size = 5
activations = {}

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
        
    W = np.random.randn(node_num, node_num) * 1
    a = np.dot(x,w)
    z = sigmoid(a)
    activations[i] = z

# %%
a= {1,2}
a
# Out:
# {1, 2}

# %%
a[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-6a1284577a36> in <module>()
# ----> 1 a[0]
#
# TypeError: 'set' object does not support indexing

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def ReLU(x):
    return np.maximum(0, x)


def tanh(x):
    return np.tanh(x)
    
input_data = np.random.randn(1000, 100)  # 1000개의 데이터
node_num = 100  # 각 은닉층의 노드(뉴런) 수
hidden_layer_size = 5  # 은닉층이 5개
activations = {}  # 이곳에 활성화 결과를 저장

x = input_data

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]

    # 초깃값을 다양하게 바꿔가며 실험해보자！
    w = np.random.randn(node_num, node_num) * 1
    # w = np.random.randn(node_num, node_num) * 0.01
    # w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num)
    # w = np.random.randn(node_num, node_num) * np.sqrt(2.0 / node_num)


    a = np.dot(x, w)


    # 활성화 함수도 바꿔가며 실험해보자！
    z = sigmoid(a)
    # z = ReLU(a)
    # z = tanh(a)

    activations[i] = z

# 히스토그램 그리기
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    if i != 0: plt.yticks([], [])
    # plt.xlim(0.1, 1)
    # plt.ylim(0, 7000)
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def ReLU(x):
    return np.maximum(0, x)


def tanh(x):
    return np.tanh(x)
    
input_data = np.random.randn(1000, 100)  # 1000개의 데이터
node_num = 100  # 각 은닉층의 노드(뉴런) 수
hidden_layer_size = 5  # 은닉층이 5개
activations = {}  # 이곳에 활성화 결과를 저장

x = input_data

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]

    # 초깃값을 다양하게 바꿔가며 실험해보자！
    w = np.random.randn(node_num, node_num) * 0.01
    # w = np.random.randn(node_num, node_num) * 0.01
    # w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num)
    # w = np.random.randn(node_num, node_num) * np.sqrt(2.0 / node_num)


    a = np.dot(x, w)


    # 활성화 함수도 바꿔가며 실험해보자！
    z = sigmoid(a)
    # z = ReLU(a)
    # z = tanh(a)

    activations[i] = z

# 히스토그램 그리기
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    if i != 0: plt.yticks([], [])
    # plt.xlim(0.1, 1)
    # plt.ylim(0, 7000)
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt


def sigmoid(x):
    return 1 / (1 + np.exp(-x))


def ReLU(x):
    return np.maximum(0, x)


def tanh(x):
    return np.tanh(x)
    
input_data = np.random.randn(1000, 100)  # 1000개의 데이터
node_num = 100  # 각 은닉층의 노드(뉴런) 수
hidden_layer_size = 5  # 은닉층이 5개
activations = {}  # 이곳에 활성화 결과를 저장

x = input_data

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]

    # 초깃값을 다양하게 바꿔가며 실험해보자！
    w = np.random.randn(node_num, node_num) / np.sqrt(node_num)
    # w = np.random.randn(node_num, node_num) * 0.01
    # w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num)
    # w = np.random.randn(node_num, node_num) * np.sqrt(2.0 / node_num)


    a = np.dot(x, w)


    # 활성화 함수도 바꿔가며 실험해보자！
    z = sigmoid(a)
    # z = ReLU(a)
    # z = tanh(a)

    activations[i] = z

# 히스토그램 그리기
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    if i != 0: plt.yticks([], [])
    # plt.xlim(0.1, 1)
    # plt.ylim(0, 7000)
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
import os, sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.util import smooth_curve
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD


# 0. MNIST 데이터 읽기==========
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000


# 1. 실험용 설정==========
weight_init_types = {'std=0.01': 0.01, 'Xavier': 'sigmoid', 'He': 'relu'}
optimizer = SGD(lr=0.01)

networks = {}
train_loss = {}
for key, weight_type in weight_init_types.items():
    networks[key] = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100],
                                  output_size=10, weight_init_std=weight_type)
    train_loss[key] = []


# 2. 훈련 시작==========
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in weight_init_types.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizer.update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print("===========" + "iteration:" + str(i) + "===========")
        for key in weight_init_types.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))


# 3. 그래프 그리기==========
markers = {'std=0.01': 'o', 'Xavier': 's', 'He': 'D'}
x = np.arange(max_iterations)
for key in weight_init_types.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 2.5)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# std=0.01:2.3025279439848
# Xavier:2.310832882173579
# He:2.4243486437396315
# ===========iteration:100===========
# std=0.01:2.30246060572033
# Xavier:2.2385105763987205
# He:1.3427309245991002
# ===========iteration:200===========
# std=0.01:2.302532877363269
# Xavier:2.1416836995631767
# He:0.5674805258414404
# ===========iteration:300===========
# std=0.01:2.302149861536912
# Xavier:1.7994313595990277
# He:0.5092515875754078
# ===========iteration:400===========
# std=0.01:2.300515822424277
# Xavier:1.3363861301017361
# He:0.4919655479429904
# ===========iteration:500===========
# std=0.01:2.3001289907621354
# Xavier:0.7909948955806603
# He:0.2898953369205385
# ===========iteration:600===========
# std=0.01:2.3058776096722826
# Xavier:0.7489441031775105
# He:0.2944731106984451
# ===========iteration:700===========
# std=0.01:2.299975291926174
# Xavier:0.6143868240945677
# He:0.3436409367614505
# ===========iteration:800===========
# std=0.01:2.3060636988249383
# Xavier:0.46274116918044816
# He:0.2510241946887307
# ===========iteration:900===========
# std=0.01:2.3053139187704987
# Xavier:0.46824780139793054
# He:0.3184392666352001
# ===========iteration:1000===========
# std=0.01:2.301522072491832
# Xavier:0.4390718019474176
# He:0.26964917141846567
# ===========iteration:1100===========
# std=0.01:2.3025709232746685
# Xavier:0.4668191048372
# He:0.26942849617075887
# ===========iteration:1200===========
# std=0.01:2.3000514397489127
# Xavier:0.37753937851222696
# He:0.25177567048165017
# ===========iteration:1300===========
# std=0.01:2.2975712738041967
# Xavier:0.4217895529571539
# He:0.23816898469761336
# ===========iteration:1400===========
# std=0.01:2.301315969327827
# Xavier:0.3197493125461295
# He:0.24287277682173966
# ===========iteration:1500===========
# std=0.01:2.302067693255273
# Xavier:0.30958508880220104
# He:0.16771182891580688
# ===========iteration:1600===========
# std=0.01:2.3019293655057376
# Xavier:0.37259940869221475
# He:0.24926938477994387
# ===========iteration:1700===========
# std=0.01:2.302360425236456
# Xavier:0.2753063593248465
# He:0.15574881358505216
# ===========iteration:1800===========
# std=0.01:2.2958945002622335
# Xavier:0.31063310523883547
# He:0.2506518669272251
# ===========iteration:1900===========
# std=0.01:2.2970823346530587
# Xavier:0.15813725704574386
# He:0.08187086538705993

# %%
import os
import sys

sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.12, test acc:0.1086
# epoch:1, train acc:0.13, test acc:0.1248
# epoch:2, train acc:0.15666666666666668, test acc:0.134
# epoch:3, train acc:0.2, test acc:0.1489
# epoch:4, train acc:0.20333333333333334, test acc:0.16
# epoch:5, train acc:0.20333333333333334, test acc:0.1626
# epoch:6, train acc:0.20666666666666667, test acc:0.1608
# epoch:7, train acc:0.21333333333333335, test acc:0.1663
# epoch:8, train acc:0.21, test acc:0.1673
# epoch:9, train acc:0.22666666666666666, test acc:0.1717
# epoch:10, train acc:0.22666666666666666, test acc:0.1727
# epoch:11, train acc:0.25, test acc:0.1856
# epoch:12, train acc:0.25, test acc:0.1841
# epoch:13, train acc:0.26666666666666666, test acc:0.1969
# epoch:14, train acc:0.2866666666666667, test acc:0.2049
# epoch:15, train acc:0.30333333333333334, test acc:0.2201
# epoch:16, train acc:0.29333333333333333, test acc:0.2222
# epoch:17, train acc:0.30666666666666664, test acc:0.2366
# epoch:18, train acc:0.32666666666666666, test acc:0.2474
# epoch:19, train acc:0.35333333333333333, test acc:0.266
# epoch:20, train acc:0.38333333333333336, test acc:0.2796
# epoch:21, train acc:0.4, test acc:0.2818
# epoch:22, train acc:0.4033333333333333, test acc:0.2845
# epoch:23, train acc:0.41, test acc:0.2951
# epoch:24, train acc:0.4, test acc:0.2965
# epoch:25, train acc:0.44666666666666666, test acc:0.3095
# epoch:26, train acc:0.47333333333333333, test acc:0.3194
# epoch:27, train acc:0.4533333333333333, test acc:0.3223
# epoch:28, train acc:0.4633333333333333, test acc:0.3323
# epoch:29, train acc:0.49, test acc:0.3396
# epoch:30, train acc:0.49, test acc:0.3428
# epoch:31, train acc:0.49, test acc:0.3478
# epoch:32, train acc:0.48333333333333334, test acc:0.3461
# epoch:33, train acc:0.49333333333333335, test acc:0.3696
# epoch:34, train acc:0.5266666666666666, test acc:0.3871
# epoch:35, train acc:0.5166666666666667, test acc:0.3828
# epoch:36, train acc:0.5333333333333333, test acc:0.3925
# epoch:37, train acc:0.53, test acc:0.3972
# epoch:38, train acc:0.5566666666666666, test acc:0.4119
# epoch:39, train acc:0.56, test acc:0.4173
# epoch:40, train acc:0.5833333333333334, test acc:0.4319
# epoch:41, train acc:0.6033333333333334, test acc:0.4447
# epoch:42, train acc:0.6033333333333334, test acc:0.4506
# epoch:43, train acc:0.6233333333333333, test acc:0.4581
# epoch:44, train acc:0.63, test acc:0.457
# epoch:45, train acc:0.63, test acc:0.4592
# epoch:46, train acc:0.65, test acc:0.4707
# epoch:47, train acc:0.6233333333333333, test acc:0.4618
# epoch:48, train acc:0.6633333333333333, test acc:0.4815
# epoch:49, train acc:0.6766666666666666, test acc:0.4924
# epoch:50, train acc:0.65, test acc:0.4849
# epoch:51, train acc:0.6433333333333333, test acc:0.483
# epoch:52, train acc:0.69, test acc:0.5048
# epoch:53, train acc:0.6866666666666666, test acc:0.5065
# epoch:54, train acc:0.7033333333333334, test acc:0.5115
# epoch:55, train acc:0.7033333333333334, test acc:0.5026
# epoch:56, train acc:0.72, test acc:0.5255
# epoch:57, train acc:0.7166666666666667, test acc:0.5272
# epoch:58, train acc:0.6966666666666667, test acc:0.5242
# epoch:59, train acc:0.7133333333333334, test acc:0.5234
# epoch:60, train acc:0.7133333333333334, test acc:0.5397
# epoch:61, train acc:0.72, test acc:0.5351
# epoch:62, train acc:0.71, test acc:0.53
# epoch:63, train acc:0.73, test acc:0.5457
# epoch:64, train acc:0.7266666666666667, test acc:0.5549
# epoch:65, train acc:0.7433333333333333, test acc:0.559
# epoch:66, train acc:0.72, test acc:0.5505
# epoch:67, train acc:0.73, test acc:0.5553
# epoch:68, train acc:0.74, test acc:0.5602
# epoch:69, train acc:0.75, test acc:0.5644
# epoch:70, train acc:0.76, test acc:0.5818
# epoch:71, train acc:0.7366666666666667, test acc:0.5711
# epoch:72, train acc:0.7633333333333333, test acc:0.582
# epoch:73, train acc:0.75, test acc:0.587
# epoch:74, train acc:0.76, test acc:0.6012
# epoch:75, train acc:0.7633333333333333, test acc:0.6004
# epoch:76, train acc:0.7666666666666667, test acc:0.5956
# epoch:77, train acc:0.7666666666666667, test acc:0.5997
# epoch:78, train acc:0.7566666666666667, test acc:0.602
# epoch:79, train acc:0.77, test acc:0.6122
# epoch:80, train acc:0.77, test acc:0.6099
# epoch:81, train acc:0.7866666666666666, test acc:0.6081
# epoch:82, train acc:0.79, test acc:0.6207
# epoch:83, train acc:0.8033333333333333, test acc:0.6181
# epoch:84, train acc:0.79, test acc:0.6148
# epoch:85, train acc:0.79, test acc:0.6241
# epoch:86, train acc:0.8133333333333334, test acc:0.6112
# epoch:87, train acc:0.7933333333333333, test acc:0.6228
# epoch:88, train acc:0.8066666666666666, test acc:0.6302
# epoch:89, train acc:0.79, test acc:0.6304
# epoch:90, train acc:0.7966666666666666, test acc:0.6324
# epoch:91, train acc:0.7966666666666666, test acc:0.6287
# epoch:92, train acc:0.81, test acc:0.6351
# epoch:93, train acc:0.8133333333333334, test acc:0.6302
# epoch:94, train acc:0.8166666666666667, test acc:0.621
# epoch:95, train acc:0.8166666666666667, test acc:0.6245
# epoch:96, train acc:0.8166666666666667, test acc:0.6335
# epoch:97, train acc:0.8033333333333333, test acc:0.6301
# epoch:98, train acc:0.8133333333333334, test acc:0.6318
# epoch:99, train acc:0.8066666666666666, test acc:0.6397
# epoch:100, train acc:0.8233333333333334, test acc:0.6331
# epoch:101, train acc:0.82, test acc:0.635
# epoch:102, train acc:0.8266666666666667, test acc:0.6149
# epoch:103, train acc:0.81, test acc:0.6348
# epoch:104, train acc:0.8333333333333334, test acc:0.6395
# epoch:105, train acc:0.8166666666666667, test acc:0.6434
# epoch:106, train acc:0.84, test acc:0.6354
# epoch:107, train acc:0.8466666666666667, test acc:0.6448
# epoch:108, train acc:0.84, test acc:0.6462
# epoch:109, train acc:0.8366666666666667, test acc:0.6336
# epoch:110, train acc:0.8433333333333334, test acc:0.652
# epoch:111, train acc:0.8333333333333334, test acc:0.6506
# epoch:112, train acc:0.8266666666666667, test acc:0.6432
# epoch:113, train acc:0.8266666666666667, test acc:0.6524
# epoch:114, train acc:0.8366666666666667, test acc:0.6367
# epoch:115, train acc:0.8333333333333334, test acc:0.6312
# epoch:116, train acc:0.8333333333333334, test acc:0.6414
# epoch:117, train acc:0.8533333333333334, test acc:0.6484
# epoch:118, train acc:0.85, test acc:0.6529
# epoch:119, train acc:0.8433333333333334, test acc:0.6476
# epoch:120, train acc:0.8533333333333334, test acc:0.641
# epoch:121, train acc:0.8466666666666667, test acc:0.6437
# epoch:122, train acc:0.84, test acc:0.644
# epoch:123, train acc:0.84, test acc:0.6437
# epoch:124, train acc:0.8333333333333334, test acc:0.6386
# epoch:125, train acc:0.8366666666666667, test acc:0.6481
# epoch:126, train acc:0.83, test acc:0.6517
# epoch:127, train acc:0.85, test acc:0.6559
# epoch:128, train acc:0.8466666666666667, test acc:0.6647
# epoch:129, train acc:0.8466666666666667, test acc:0.6543
# epoch:130, train acc:0.83, test acc:0.658
# epoch:131, train acc:0.84, test acc:0.6579
# epoch:132, train acc:0.84, test acc:0.6511
# epoch:133, train acc:0.8533333333333334, test acc:0.6432
# epoch:134, train acc:0.8466666666666667, test acc:0.6529
# epoch:135, train acc:0.8466666666666667, test acc:0.6491
# epoch:136, train acc:0.8433333333333334, test acc:0.6462
# epoch:137, train acc:0.8466666666666667, test acc:0.6548
# epoch:138, train acc:0.84, test acc:0.6662
# epoch:139, train acc:0.85, test acc:0.6584
# epoch:140, train acc:0.8566666666666667, test acc:0.6612
# epoch:141, train acc:0.8366666666666667, test acc:0.6521
# epoch:142, train acc:0.8466666666666667, test acc:0.6599
# epoch:143, train acc:0.8666666666666667, test acc:0.6597
# epoch:144, train acc:0.8466666666666667, test acc:0.6704
# epoch:145, train acc:0.8466666666666667, test acc:0.667
# epoch:146, train acc:0.85, test acc:0.6684
# epoch:147, train acc:0.8433333333333334, test acc:0.6559
# epoch:148, train acc:0.86, test acc:0.6495
# epoch:149, train acc:0.86, test acc:0.6677
# epoch:150, train acc:0.8533333333333334, test acc:0.6619
# epoch:151, train acc:0.8566666666666667, test acc:0.6537
# epoch:152, train acc:0.86, test acc:0.664
# epoch:153, train acc:0.87, test acc:0.6566
# epoch:154, train acc:0.85, test acc:0.6577
# epoch:155, train acc:0.8633333333333333, test acc:0.6525
# epoch:156, train acc:0.8566666666666667, test acc:0.6548
# epoch:157, train acc:0.85, test acc:0.6417
# epoch:158, train acc:0.8566666666666667, test acc:0.6594
# epoch:159, train acc:0.85, test acc:0.6554
# epoch:160, train acc:0.85, test acc:0.6565
# epoch:161, train acc:0.8533333333333334, test acc:0.658
# epoch:162, train acc:0.8533333333333334, test acc:0.6472
# epoch:163, train acc:0.8433333333333334, test acc:0.6491
# epoch:164, train acc:0.8466666666666667, test acc:0.6592
# epoch:165, train acc:0.8433333333333334, test acc:0.6637
# epoch:166, train acc:0.8366666666666667, test acc:0.6629
# epoch:167, train acc:0.8433333333333334, test acc:0.664
# epoch:168, train acc:0.8533333333333334, test acc:0.6661
# epoch:169, train acc:0.8466666666666667, test acc:0.656
# epoch:170, train acc:0.8366666666666667, test acc:0.6677
# epoch:171, train acc:0.84, test acc:0.6517
# epoch:172, train acc:0.8266666666666667, test acc:0.654
# epoch:173, train acc:0.8366666666666667, test acc:0.6686
# epoch:174, train acc:0.83, test acc:0.6613
# epoch:175, train acc:0.85, test acc:0.672
# epoch:176, train acc:0.85, test acc:0.6704
# epoch:177, train acc:0.8433333333333334, test acc:0.6591
# epoch:178, train acc:0.8366666666666667, test acc:0.6687
# epoch:179, train acc:0.8566666666666667, test acc:0.6667
# epoch:180, train acc:0.84, test acc:0.6615
# epoch:181, train acc:0.8433333333333334, test acc:0.6574
# epoch:182, train acc:0.85, test acc:0.658
# epoch:183, train acc:0.8466666666666667, test acc:0.6516
# epoch:184, train acc:0.8566666666666667, test acc:0.6665
# epoch:185, train acc:0.86, test acc:0.6685
# epoch:186, train acc:0.8533333333333334, test acc:0.6684
# epoch:187, train acc:0.8566666666666667, test acc:0.6671
# epoch:188, train acc:0.86, test acc:0.6687
# epoch:189, train acc:0.8633333333333333, test acc:0.6768
# epoch:190, train acc:0.86, test acc:0.6742
# epoch:191, train acc:0.8533333333333334, test acc:0.6665
# epoch:192, train acc:0.85, test acc:0.6711
# epoch:193, train acc:0.85, test acc:0.6726
# epoch:194, train acc:0.8533333333333334, test acc:0.6766
# epoch:195, train acc:0.8566666666666667, test acc:0.6721
# epoch:196, train acc:0.8566666666666667, test acc:0.674
# epoch:197, train acc:0.8466666666666667, test acc:0.6579
# epoch:198, train acc:0.85, test acc:0.6622
# epoch:199, train acc:0.8433333333333334, test acc:0.6597
# epoch:200, train acc:0.8533333333333334, test acc:0.6713

# %%
class Dropout:
    def __init_(self, droupout_ratio=0.5):
        self.dropout_ratio = dropout_ratio
        self.mask = None
        
    def forward(self, x, train_flg_True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x* (1.0 - self.dropout_ratio)
        
    def backward(self, dout):
        return dout * self.mask

# %%
import os
import sys
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# 드롭아웃 사용 유무와 비울 설정 ========================
use_dropout = True  # 드롭아웃을 쓰지 않을 때는 False
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.303414845006907
# === epoch:1, train acc:0.09, test acc:0.1009 ===
# train loss:2.2969190684788443
# train loss:2.30509569819994
# train loss:2.3085214381131305
# === epoch:2, train acc:0.09333333333333334, test acc:0.1031 ===
# train loss:2.3007808927948714
# train loss:2.307934543252647
# train loss:2.3069716977139123
# === epoch:3, train acc:0.09, test acc:0.1041 ===
# train loss:2.2972525419571133
# train loss:2.3026874400828476
# train loss:2.2991413804770406
# === epoch:4, train acc:0.09333333333333334, test acc:0.1089 ===
# train loss:2.305028558612885
# train loss:2.2972680635790836
# train loss:2.29148340070845
# === epoch:5, train acc:0.12333333333333334, test acc:0.1113 ===
# train loss:2.307159068431415
# train loss:2.301697303135935
# train loss:2.303169172239113
# === epoch:6, train acc:0.11666666666666667, test acc:0.1157 ===
# train loss:2.2989084861128335
# train loss:2.285007979344672
# train loss:2.2970115138504825
# === epoch:7, train acc:0.14333333333333334, test acc:0.124 ===
# train loss:2.292028575799661
# train loss:2.2965999206432905
# train loss:2.2802012707771335
# === epoch:8, train acc:0.13666666666666666, test acc:0.128 ===
# train loss:2.28955055775462
# train loss:2.2755601661401728
# train loss:2.2903129408106166
# === epoch:9, train acc:0.15333333333333332, test acc:0.132 ===
# train loss:2.295150736677269
# train loss:2.2897545052313517
# train loss:2.2918327220877797
# === epoch:10, train acc:0.16666666666666666, test acc:0.1411 ===
# train loss:2.283921720183243
# train loss:2.294489153704041
# train loss:2.2813818394222944
# === epoch:11, train acc:0.17333333333333334, test acc:0.1497 ===
# train loss:2.279260951335188
# train loss:2.279970860167129
# train loss:2.287244779975424
# === epoch:12, train acc:0.18, test acc:0.1543 ===
# train loss:2.2853878488283406
# train loss:2.281890276716905
# train loss:2.284770030950838
# === epoch:13, train acc:0.19333333333333333, test acc:0.1596 ===
# train loss:2.2828021394105944
# train loss:2.2771155410734507
# train loss:2.2775788048949384
# === epoch:14, train acc:0.21, test acc:0.1646 ===
# train loss:2.2916949132656708
# train loss:2.284374216845361
# train loss:2.2760599808188973
# === epoch:15, train acc:0.21666666666666667, test acc:0.1696 ===
# train loss:2.2674281851687907
# train loss:2.278800781427956
# train loss:2.280587978649477
# === epoch:16, train acc:0.24333333333333335, test acc:0.1775 ===
# train loss:2.2797489435170983
# train loss:2.2796252390070855
# train loss:2.279646720685732
# === epoch:17, train acc:0.24, test acc:0.1822 ===
# train loss:2.2641435870291904
# train loss:2.283001117466426
# train loss:2.2851178170505118
# === epoch:18, train acc:0.23666666666666666, test acc:0.1838 ===
# train loss:2.2787853540944782
# train loss:2.2728866354986756
# train loss:2.2469495278392495
# === epoch:19, train acc:0.25666666666666665, test acc:0.1903 ===
# train loss:2.272231046429793
# train loss:2.2786203920201538
# train loss:2.265743302133786
# === epoch:20, train acc:0.26666666666666666, test acc:0.1938 ===
# train loss:2.2658143881312216
# train loss:2.2719767091861565
# train loss:2.273727629405386
# === epoch:21, train acc:0.27666666666666667, test acc:0.1996 ===
# train loss:2.2626450528033697
# train loss:2.2776206802972556
# train loss:2.272470520108726
# === epoch:22, train acc:0.29, test acc:0.2051 ===
# train loss:2.2710470917044656
# train loss:2.2646249376019685
# train loss:2.25808724635654
# === epoch:23, train acc:0.29333333333333333, test acc:0.2099 ===
# train loss:2.264401895273652
# train loss:2.2813951507097276
# train loss:2.268491100209673
# === epoch:24, train acc:0.30333333333333334, test acc:0.2135 ===
# train loss:2.2771235458396784
# train loss:2.263814831479336
# train loss:2.262691876370686
# === epoch:25, train acc:0.32666666666666666, test acc:0.2194 ===
# train loss:2.276598378042197
# train loss:2.2669984335374607
# train loss:2.273798473606125
# === epoch:26, train acc:0.3233333333333333, test acc:0.2232 ===
# train loss:2.2723685287063287
# train loss:2.2699359629925264
# train loss:2.2469836524352913
# === epoch:27, train acc:0.3433333333333333, test acc:0.2249 ===
# train loss:2.263579042717754
# train loss:2.257063417396656
# train loss:2.25191839194773
# === epoch:28, train acc:0.35333333333333333, test acc:0.2289 ===
# train loss:2.256324835272915
# train loss:2.2629685227360845
# train loss:2.2571495171338
# === epoch:29, train acc:0.3566666666666667, test acc:0.2329 ===
# train loss:2.2462821364639156
# train loss:2.255976373958588
# train loss:2.2389771915120438
# === epoch:30, train acc:0.3566666666666667, test acc:0.2335 ===
# train loss:2.264795417581821
# train loss:2.240565896555207
# train loss:2.2431552080106805
# === epoch:31, train acc:0.36333333333333334, test acc:0.2395 ===
# train loss:2.2597804493563323
# train loss:2.2562642911371853
# train loss:2.253907182216517
# === epoch:32, train acc:0.37666666666666665, test acc:0.2432 ===
# train loss:2.2561691193417808
# train loss:2.2549969800094045
# train loss:2.2520813299716456
# === epoch:33, train acc:0.37666666666666665, test acc:0.2428 ===
# train loss:2.2387801073288243
# train loss:2.245314241764539
# train loss:2.254325329265108
# === epoch:34, train acc:0.37666666666666665, test acc:0.2434 ===
# train loss:2.257232524318995
# train loss:2.2465302345295273
# train loss:2.2522151768095324
# === epoch:35, train acc:0.38, test acc:0.2462 ===
# train loss:2.256911691865171
# train loss:2.2662155409671767
# train loss:2.250400343271207
# === epoch:36, train acc:0.37666666666666665, test acc:0.2493 ===
# train loss:2.2438229868325252
# train loss:2.241535437069185
# train loss:2.234596419441618
# === epoch:37, train acc:0.37666666666666665, test acc:0.2519 ===
# train loss:2.264771996730568
# train loss:2.2491012596745086
# train loss:2.2447775560201912
# === epoch:38, train acc:0.38333333333333336, test acc:0.2578 ===
# train loss:2.2430318181050426
# train loss:2.2343713959676874
# train loss:2.248730551487697
# === epoch:39, train acc:0.37666666666666665, test acc:0.2563 ===
# train loss:2.265271603191074
# train loss:2.247340153965164
# train loss:2.2617224406613405
# === epoch:40, train acc:0.37333333333333335, test acc:0.257 ===
# train loss:2.2413872424937034
# train loss:2.232832280773302
# train loss:2.253490516488493
# === epoch:41, train acc:0.38, test acc:0.2617 ===
# train loss:2.251324220105744
# train loss:2.228120283271923
# train loss:2.239003280411625
# === epoch:42, train acc:0.38666666666666666, test acc:0.2629 ===
# train loss:2.24772477450028
# train loss:2.2540451944579387
# train loss:2.230483197839101
# === epoch:43, train acc:0.37, test acc:0.2612 ===
# train loss:2.2329642442077486
# train loss:2.2336025103924024
# train loss:2.2354949098721235
# === epoch:44, train acc:0.36, test acc:0.2576 ===
# train loss:2.2270872040479746
# train loss:2.2605673334019105
# train loss:2.2343185218460193
# === epoch:45, train acc:0.36333333333333334, test acc:0.258 ===
# train loss:2.256666634456102
# train loss:2.223973531671799
# train loss:2.2285014207354648
# === epoch:46, train acc:0.36666666666666664, test acc:0.2586 ===
# train loss:2.2520825542464995
# train loss:2.2180902859514795
# train loss:2.2220447195209205
# === epoch:47, train acc:0.37, test acc:0.2572 ===
# train loss:2.2233962069373954
# train loss:2.222266342733218
# train loss:2.242500803378528
# === epoch:48, train acc:0.37333333333333335, test acc:0.2557 ===
# train loss:2.237190404957591
# train loss:2.2161198478979687
# train loss:2.2402602741548914
# === epoch:49, train acc:0.37, test acc:0.254 ===
# train loss:2.2218119854493796
# train loss:2.2449467774686607
# train loss:2.2355095477572284
# === epoch:50, train acc:0.37333333333333335, test acc:0.2566 ===
# train loss:2.2235468286050257
# train loss:2.2438735638339837
# train loss:2.219243277459034
# === epoch:51, train acc:0.37, test acc:0.2537 ===
# train loss:2.2128926392318524
# train loss:2.2258911400693466
# train loss:2.2462044479692618
# === epoch:52, train acc:0.36333333333333334, test acc:0.2482 ===
# train loss:2.2540427779184524
# train loss:2.224016714193193
# train loss:2.2196812224480102
# === epoch:53, train acc:0.37, test acc:0.2503 ===
# train loss:2.2210414442845834
# train loss:2.2143683954954074
# train loss:2.210210041046949
# === epoch:54, train acc:0.38, test acc:0.2527 ===
# train loss:2.23170593397895
# train loss:2.2448813800305314
# train loss:2.2082131652235155
# === epoch:55, train acc:0.38333333333333336, test acc:0.2563 ===
# train loss:2.222756384463785
# train loss:2.2064450149718122
# train loss:2.213710875117861
# === epoch:56, train acc:0.37333333333333335, test acc:0.2537 ===
# train loss:2.2216027808376815
# train loss:2.22989630865147
# train loss:2.2266104507462554
# === epoch:57, train acc:0.38, test acc:0.2573 ===
# train loss:2.1890247791978736
# train loss:2.21407347152339
# train loss:2.208306490059543
# === epoch:58, train acc:0.37333333333333335, test acc:0.2553 ===
# train loss:2.2114305546926314
# train loss:2.204913847813486
# train loss:2.194586466995869
# === epoch:59, train acc:0.37333333333333335, test acc:0.2553 ===
# train loss:2.209521706357711
# train loss:2.231185429534499
# train loss:2.195711246321971
# === epoch:60, train acc:0.38, test acc:0.2572 ===
# train loss:2.201931463747464
# train loss:2.216049823298689
# train loss:2.1990441592768755
# === epoch:61, train acc:0.37, test acc:0.2578 ===
# train loss:2.2096935721521804
# train loss:2.1966225489140667
# train loss:2.204322843269649
# === epoch:62, train acc:0.37, test acc:0.2533 ===
# train loss:2.208275733711181
# train loss:2.2068711383982444
# train loss:2.2047695051769676
# === epoch:63, train acc:0.36666666666666664, test acc:0.2509 ===
# train loss:2.200664875032677
# train loss:2.194932130555781
# train loss:2.2013345882506443
# === epoch:64, train acc:0.3566666666666667, test acc:0.2471 ===
# train loss:2.1749438286035243
# train loss:2.181383351019705
# train loss:2.188023043636026
# === epoch:65, train acc:0.35333333333333333, test acc:0.2451 ===
# train loss:2.2029633917080265
# train loss:2.1976507296774908
# train loss:2.196978371657142
# === epoch:66, train acc:0.35333333333333333, test acc:0.2453 ===
# train loss:2.217353706108875
# train loss:2.190317471465455
# train loss:2.1999543786841396
# === epoch:67, train acc:0.3566666666666667, test acc:0.25 ===
# train loss:2.1945362884326385
# train loss:2.191839635228902
# train loss:2.187185721791229
# === epoch:68, train acc:0.35333333333333333, test acc:0.2488 ===
# train loss:2.1818700567514315
# train loss:2.185701298766149
# train loss:2.1764066618707627
# === epoch:69, train acc:0.36, test acc:0.247 ===
# train loss:2.1801281918347577
# train loss:2.1765399451470957
# train loss:2.1924388620658273
# === epoch:70, train acc:0.36, test acc:0.2451 ===
# train loss:2.1949240900903315
# train loss:2.1994033546170466
# train loss:2.1571458725162973
# === epoch:71, train acc:0.36, test acc:0.245 ===
# train loss:2.1402665682944444
# train loss:2.162510387719876
# train loss:2.2067754833276756
# === epoch:72, train acc:0.36, test acc:0.2465 ===
# train loss:2.204539665328484
# train loss:2.176960321511374
# train loss:2.1881996591002797
# === epoch:73, train acc:0.36333333333333334, test acc:0.2494 ===
# train loss:2.203134730571192
# train loss:2.2022617109092555
# train loss:2.193060502260831
# === epoch:74, train acc:0.37333333333333335, test acc:0.2586 ===
# train loss:2.189352208785731
# train loss:2.2234675527567465
# train loss:2.194247239436898
# === epoch:75, train acc:0.37333333333333335, test acc:0.2644 ===
# train loss:2.1780780258272396
# train loss:2.1830082565756013
# train loss:2.168935799769501
# === epoch:76, train acc:0.37333333333333335, test acc:0.2645 ===
# train loss:2.1312541654413817
# train loss:2.1984360037502655
# train loss:2.198929512046532
# === epoch:77, train acc:0.36666666666666664, test acc:0.2628 ===
# train loss:2.1719866171155378
# train loss:2.1659383059591506
# train loss:2.182210073484783
# === epoch:78, train acc:0.37333333333333335, test acc:0.2655 ===
# train loss:2.166175451033636
# train loss:2.177279503586038
# train loss:2.1750875847043543
# === epoch:79, train acc:0.37, test acc:0.2676 ===
# train loss:2.1736044543331245
# train loss:2.1480524252320006
# train loss:2.180842905577559
# === epoch:80, train acc:0.37, test acc:0.2713 ===
# train loss:2.162199569272534
# train loss:2.1429544907117153
# train loss:2.1675787617384468
# === epoch:81, train acc:0.38, test acc:0.2748 ===
# train loss:2.1409318737043077
# train loss:2.140016923086453
# train loss:2.181491105348308
# === epoch:82, train acc:0.37666666666666665, test acc:0.2741 ===
# train loss:2.202711415840377
# train loss:2.1511069911309715
# train loss:2.1593154766485796
# === epoch:83, train acc:0.38, test acc:0.2757 ===
# train loss:2.1383060376503407
# train loss:2.158607133454957
# train loss:2.1548895123906626
# === epoch:84, train acc:0.38333333333333336, test acc:0.2782 ===
# train loss:2.1824825352925643
# train loss:2.138661493533299
# train loss:2.142400496727238
# === epoch:85, train acc:0.38333333333333336, test acc:0.2803 ===
# train loss:2.1746483525841045
# train loss:2.14852245815623
# train loss:2.125964510261883
# === epoch:86, train acc:0.38, test acc:0.2783 ===
# train loss:2.1115848344818784
# train loss:2.142121458875211
# train loss:2.120296078954979
# === epoch:87, train acc:0.37666666666666665, test acc:0.2755 ===
# train loss:2.149585689987192
# train loss:2.126648019484001
# train loss:2.160354607481617
# === epoch:88, train acc:0.37333333333333335, test acc:0.2753 ===
# train loss:2.132231917011982
# train loss:2.1516166715648684
# train loss:2.180999622976396
# === epoch:89, train acc:0.38333333333333336, test acc:0.2829 ===
# train loss:2.172232442891568
# train loss:2.1278352845493838
# train loss:2.1513033415717855
# === epoch:90, train acc:0.39666666666666667, test acc:0.2934 ===
# train loss:2.142140625191469
# train loss:2.150673376228812
# train loss:2.108923406913833
# === epoch:91, train acc:0.39666666666666667, test acc:0.2921 ===
# train loss:2.167606316393229
# train loss:2.1691059455236705
# train loss:2.135711007779695
# === epoch:92, train acc:0.4, test acc:0.2932 ===
# train loss:2.1450106870270416
# train loss:2.1444251441229794
# train loss:2.124247549673454
# === epoch:93, train acc:0.4, test acc:0.2944 ===
# train loss:2.1061969506213907
# train loss:2.1167762780806165
# train loss:2.1565935015473987
# === epoch:94, train acc:0.4, test acc:0.2948 ===
# train loss:2.114487729851265
# train loss:2.1184189233969293
# train loss:2.100201798106247
# === epoch:95, train acc:0.39666666666666667, test acc:0.2968 ===
# train loss:2.142539132846721
# train loss:2.13795349497687
# train loss:2.0893392290339508
# === epoch:96, train acc:0.4, test acc:0.2961 ===
# train loss:2.1104737303810284
# train loss:2.1114284775238543
# train loss:2.0954580752969356
# === epoch:97, train acc:0.4033333333333333, test acc:0.2986 ===
# train loss:2.1129862045856194
# train loss:2.0914708522440706
# train loss:2.1218066038068177
# === epoch:98, train acc:0.4, test acc:0.2962 ===
# train loss:2.133158887133284
# train loss:2.0895433747870955
# train loss:2.0972044947971114
# === epoch:99, train acc:0.38333333333333336, test acc:0.3005 ===
# train loss:2.0854795284356085
# train loss:2.1364035395753236
# train loss:2.1093863939757234
# === epoch:100, train acc:0.39666666666666667, test acc:0.3089 ===
# train loss:2.102655864806808
# train loss:2.1003307004800793
# train loss:2.1233047188095426
# === epoch:101, train acc:0.39666666666666667, test acc:0.3129 ===
# train loss:2.142183200748262
# train loss:2.0791297044965407
# train loss:2.0774227951537814
# === epoch:102, train acc:0.39, test acc:0.3083 ===
# train loss:2.122608901763736
# train loss:2.122631370421219
# train loss:2.073185417651352
# === epoch:103, train acc:0.3933333333333333, test acc:0.3126 ===
# train loss:1.9774354365555014
# train loss:2.0481842942399853
# train loss:2.064401208971375
# === epoch:104, train acc:0.39, test acc:0.3115 ===
# train loss:2.1407435528397003
# train loss:2.0724021516702837
# train loss:2.096010862829737
# === epoch:105, train acc:0.39, test acc:0.3143 ===
# train loss:2.1334236563425346
# train loss:2.1071785183613843
# train loss:2.1247540228258943
# === epoch:106, train acc:0.4033333333333333, test acc:0.3224 ===
# train loss:2.0721719175154827
# train loss:2.050927277190915
# train loss:2.0997886022172794
# === epoch:107, train acc:0.4066666666666667, test acc:0.3187 ===
# train loss:2.0596533203194256
# train loss:2.0442566427314404
# train loss:2.087618562254518
# === epoch:108, train acc:0.41333333333333333, test acc:0.3171 ===
# train loss:2.0795168513556233
# train loss:2.054266840763033
# train loss:2.081481448596646
# === epoch:109, train acc:0.41333333333333333, test acc:0.3189 ===
# train loss:2.0964924064459427
# train loss:2.0670042972558367
# train loss:2.0263374072188576
# === epoch:110, train acc:0.41333333333333333, test acc:0.3215 ===
# train loss:2.067628479030397
# train loss:2.1028425507457134
# train loss:2.1278369183380157
# === epoch:111, train acc:0.42, test acc:0.3273 ===
# train loss:2.0804058493388347
# train loss:2.0776979800482467
# train loss:2.0875393883408053
# === epoch:112, train acc:0.43, test acc:0.3323 ===
# train loss:2.000120650677882
# train loss:2.070596399557354
# train loss:2.047097080915872
# === epoch:113, train acc:0.42333333333333334, test acc:0.3306 ===
# train loss:2.0538008016205125
# train loss:2.0523968523831684
# train loss:2.01168122047705
# === epoch:114, train acc:0.43333333333333335, test acc:0.334 ===
# train loss:2.0561277919614485
# train loss:2.017858104530392
# train loss:2.0565301255057062
# === epoch:115, train acc:0.44, test acc:0.3342 ===
# train loss:2.018547277644658
# train loss:2.0275920126632965
# train loss:2.033107260404844
# === epoch:116, train acc:0.43, test acc:0.3342 ===
# train loss:2.042142489886508
# train loss:2.0314380239858956
# train loss:2.030432380854139
# === epoch:117, train acc:0.43666666666666665, test acc:0.3375 ===
# train loss:2.0604877794935392
# train loss:2.0504487919467875
# train loss:2.050022881695588
# === epoch:118, train acc:0.44333333333333336, test acc:0.3401 ===
# train loss:1.982714446408694
# train loss:2.024855074445419
# train loss:2.036913900875879
# === epoch:119, train acc:0.44, test acc:0.3451 ===
# train loss:2.0283367544766024
# train loss:2.0586307143645963
# train loss:2.0198141816769475
# === epoch:120, train acc:0.44, test acc:0.3486 ===
# train loss:2.037904824313599
# train loss:1.9711024639335415
# train loss:2.0084591760558648
# === epoch:121, train acc:0.44666666666666666, test acc:0.3522 ===
# train loss:2.0329334502595704
# train loss:2.0093030917957733
# train loss:2.030729054090219
# === epoch:122, train acc:0.4633333333333333, test acc:0.356 ===
# train loss:2.0277152573523196
# train loss:2.035621347852784
# train loss:2.0024043419566437
# === epoch:123, train acc:0.4666666666666667, test acc:0.3551 ===
# train loss:1.9969413451845517
# train loss:2.057352885052261
# train loss:1.8749461192933274
# === epoch:124, train acc:0.4633333333333333, test acc:0.3556 ===
# train loss:1.9683710557029905
# train loss:1.9693498604984625
# train loss:1.9443572918521297
# === epoch:125, train acc:0.4533333333333333, test acc:0.3541 ===
# train loss:1.9714854827401584
# train loss:1.905889145292755
# train loss:2.0182254892822904
# === epoch:126, train acc:0.4533333333333333, test acc:0.3573 ===
# train loss:1.9721094069733882
# train loss:2.070761569632328
# train loss:2.039389254262442
# === epoch:127, train acc:0.46, test acc:0.3585 ===
# train loss:2.012483534683819
# train loss:1.9462566563447867
# train loss:2.0430630867360007
# === epoch:128, train acc:0.4666666666666667, test acc:0.3663 ===
# train loss:2.0194919509911493
# train loss:1.93580821546526
# train loss:1.9791138669111448
# === epoch:129, train acc:0.4666666666666667, test acc:0.3674 ===
# train loss:1.8978676077582504
# train loss:1.9492922210641601
# train loss:1.9644152420335765
# === epoch:130, train acc:0.4633333333333333, test acc:0.3649 ===
# train loss:1.9742716201421704
# train loss:1.9574471620113711
# train loss:1.9465494726228831
# === epoch:131, train acc:0.4766666666666667, test acc:0.3683 ===
# train loss:1.944486489761722
# train loss:1.9106434755815351
# train loss:1.9459642705390467
# === epoch:132, train acc:0.47333333333333333, test acc:0.3692 ===
# train loss:1.9847708518917184
# train loss:1.9109027648474888
# train loss:1.935085044918722
# === epoch:133, train acc:0.48, test acc:0.3739 ===
# train loss:1.906490648295071
# train loss:1.8513086953362212
# train loss:1.9702264852867457
# === epoch:134, train acc:0.4766666666666667, test acc:0.3719 ===
# train loss:1.8827936615786476
# train loss:1.9797112668332217
# train loss:1.9877517765648491
# === epoch:135, train acc:0.47333333333333333, test acc:0.3733 ===
# train loss:1.8659814342829
# train loss:1.909280763527912
# train loss:1.9184317095228416
# === epoch:136, train acc:0.47333333333333333, test acc:0.3726 ===
# train loss:1.8973117908288994
# train loss:2.0154956053207873
# train loss:1.9749452746597462
# === epoch:137, train acc:0.4766666666666667, test acc:0.3731 ===
# train loss:1.9185926802031392
# train loss:2.005505367467018
# train loss:1.8440465414936094
# === epoch:138, train acc:0.47, test acc:0.3761 ===
# train loss:1.950423520496268
# train loss:1.9020141590689057
# train loss:1.9907908169368318
# === epoch:139, train acc:0.48333333333333334, test acc:0.3799 ===
# train loss:1.9369007692642557
# train loss:1.9319182942973965
# train loss:1.9287668371678242
# === epoch:140, train acc:0.48, test acc:0.3798 ===
# train loss:1.8331823465141397
# train loss:1.9240902605421453
# train loss:1.8727572271902326
# === epoch:141, train acc:0.48333333333333334, test acc:0.384 ===
# train loss:1.7851411392358607
# train loss:1.8631623549143794
# train loss:1.8707405891985678
# === epoch:142, train acc:0.4766666666666667, test acc:0.3806 ===
# train loss:1.8727088926143023
# train loss:1.8664328450944163
# train loss:1.8342428791523733
# === epoch:143, train acc:0.4766666666666667, test acc:0.3807 ===
# train loss:1.8970657037398362
# train loss:1.8612678907728348
# train loss:1.907497591304205
# === epoch:144, train acc:0.48, test acc:0.3806 ===
# train loss:1.8782178466549921
# train loss:1.8428438737780624
# train loss:1.759574067580556
# === epoch:145, train acc:0.4766666666666667, test acc:0.3818 ===
# train loss:1.8094869834624823
# train loss:1.781968636649853
# train loss:1.8365206104444027
# === epoch:146, train acc:0.48, test acc:0.3829 ===
# train loss:1.8833805422203218
# train loss:1.8142209317371283
# train loss:1.8137844289605818
# === epoch:147, train acc:0.48333333333333334, test acc:0.3824 ===
# train loss:1.8436622726873575
# train loss:1.7433197669974356
# train loss:1.878525672394552
# === epoch:148, train acc:0.4866666666666667, test acc:0.384 ===
# train loss:1.9060476174407557
# train loss:1.860438434550671
# train loss:1.7484764160651523
# === epoch:149, train acc:0.49, test acc:0.3857 ===
# train loss:1.8400451602935122
# train loss:1.7582724240613279
# train loss:1.860263787392515
# === epoch:150, train acc:0.49, test acc:0.386 ===
# train loss:1.8264446183641485
# train loss:1.7535955887358747
# train loss:1.8192894735518998
# === epoch:151, train acc:0.49, test acc:0.3875 ===
# train loss:1.9507510803836297
# train loss:1.7781425618729967
# train loss:1.8338510301538746
# === epoch:152, train acc:0.49, test acc:0.3889 ===
# train loss:1.9578393380611094
# train loss:1.9180773230679173
# train loss:1.8123389822855966
# === epoch:153, train acc:0.49333333333333335, test acc:0.3945 ===
# train loss:1.800408266184718
# train loss:1.7808936465934255
# train loss:1.780327100190284
# === epoch:154, train acc:0.49, test acc:0.3946 ===
# train loss:1.8533745068001475
# train loss:1.7244377355234901
# train loss:1.812147827973943
# === epoch:155, train acc:0.5, test acc:0.3973 ===
# train loss:1.8304387458380575
# train loss:1.872715725612879
# train loss:1.7910402233022114
# === epoch:156, train acc:0.49333333333333335, test acc:0.3983 ===
# train loss:1.7671465443580272
# train loss:1.722842074052586
# train loss:1.8436936305647635
# === epoch:157, train acc:0.49, test acc:0.3959 ===
# train loss:1.8145388531827746
# train loss:1.7912614953233714
# train loss:1.7813891800845016
# === epoch:158, train acc:0.48333333333333334, test acc:0.3995 ===
# train loss:1.702270628311623
# train loss:1.7983729783652418
# train loss:1.8304150015614147
# === epoch:159, train acc:0.49, test acc:0.4002 ===
# train loss:1.6873794209057769
# train loss:1.7617673302831491
# train loss:1.7373439043945371
# === epoch:160, train acc:0.4866666666666667, test acc:0.3991 ===
# train loss:1.7298423970435808
# train loss:1.6917472720470723
# train loss:1.6726495059289856
# === epoch:161, train acc:0.48333333333333334, test acc:0.3989 ===
# train loss:1.8171053890720144
# train loss:1.6392529526362203
# train loss:1.7969218737630064
# === epoch:162, train acc:0.49, test acc:0.4005 ===
# train loss:1.7236396913941379
# train loss:1.789549859750636
# train loss:1.7522260078419907
# === epoch:163, train acc:0.49666666666666665, test acc:0.4027 ===
# train loss:1.7439142547793025
# train loss:1.6794428185800425
# train loss:1.710000111305949
# === epoch:164, train acc:0.49, test acc:0.4029 ===
# train loss:1.6741201381393132
# train loss:1.6657660226753868
# train loss:1.690726316909952
# === epoch:165, train acc:0.49666666666666665, test acc:0.4032 ===
# train loss:1.7635078045332273
# train loss:1.667142885758887
# train loss:1.5442640119237345
# === epoch:166, train acc:0.5, test acc:0.405 ===
# train loss:1.6585209572171484
# train loss:1.5910778604266684
# train loss:1.681365568079538
# === epoch:167, train acc:0.5066666666666667, test acc:0.4072 ===
# train loss:1.693783495438642
# train loss:1.5910082167651054
# train loss:1.565013353152729
# === epoch:168, train acc:0.5033333333333333, test acc:0.4071 ===
# train loss:1.7259023742325146
# train loss:1.6566763086232064
# train loss:1.659877306870608
# === epoch:169, train acc:0.51, test acc:0.4083 ===
# train loss:1.5885697565645212
# train loss:1.694266658120215
# train loss:1.7048683360558359
# === epoch:170, train acc:0.51, test acc:0.411 ===
# train loss:1.711013050051741
# train loss:1.578740225629118
# train loss:1.7209378217147804
# === epoch:171, train acc:0.51, test acc:0.4113 ===
# train loss:1.7164183879556847
# train loss:1.7331271580659884
# train loss:1.6271976743068624
# === epoch:172, train acc:0.51, test acc:0.4137 ===
# train loss:1.6581600494848578
# train loss:1.757886703205841
# train loss:1.6742457269782023
# === epoch:173, train acc:0.52, test acc:0.4161 ===
# train loss:1.7179686559058573
# train loss:1.648791689076287
# train loss:1.679280437117074
# === epoch:174, train acc:0.5366666666666666, test acc:0.4243 ===
# train loss:1.6452122157653981
# train loss:1.5550977455782016
# train loss:1.6632770186746975
# === epoch:175, train acc:0.53, test acc:0.4239 ===
# train loss:1.696166393517106
# train loss:1.6924650513226793
# train loss:1.5608732134943315
# === epoch:176, train acc:0.53, test acc:0.4268 ===
# train loss:1.6813330682490724
# train loss:1.5600184558378813
# train loss:1.6497789215439451
# === epoch:177, train acc:0.5333333333333333, test acc:0.4289 ===
# train loss:1.5662510108820962
# train loss:1.576477735352833
# train loss:1.6049525570251881
# === epoch:178, train acc:0.5366666666666666, test acc:0.4295 ===
# train loss:1.6520949846345485
# train loss:1.5067807654626428
# train loss:1.4568645208111843
# === epoch:179, train acc:0.54, test acc:0.4315 ===
# train loss:1.5922725907249924
# train loss:1.4679274313136565
# train loss:1.515146159872037
# === epoch:180, train acc:0.5333333333333333, test acc:0.4273 ===
# train loss:1.431416447842708
# train loss:1.5227928805364934
# train loss:1.701756948620094
# === epoch:181, train acc:0.5266666666666666, test acc:0.4248 ===
# train loss:1.6575261555920995
# train loss:1.4429313434363893
# train loss:1.6424857400478359
# === epoch:182, train acc:0.53, test acc:0.4294 ===
# train loss:1.5760355478102182
# train loss:1.5473619677813324
# train loss:1.4717687660497554
# === epoch:183, train acc:0.5333333333333333, test acc:0.4297 ===
# train loss:1.4589716931615269
# train loss:1.5416873559107271
# train loss:1.61221174359759
# === epoch:184, train acc:0.53, test acc:0.4317 ===
# train loss:1.4000412086578737
# train loss:1.5184094430222086
# train loss:1.459822120622984
# === epoch:185, train acc:0.54, test acc:0.4333 ===
# train loss:1.5436155028372056
# train loss:1.4426066470159185
# train loss:1.6152215963289285
# === epoch:186, train acc:0.53, test acc:0.4329 ===
# train loss:1.5660115810752828
# train loss:1.5113893984383384
# train loss:1.541447370698468
# === epoch:187, train acc:0.5566666666666666, test acc:0.4424 ===
# train loss:1.502673729118638
# train loss:1.5608901686092398
# train loss:1.4839418728907763
# === epoch:188, train acc:0.5766666666666667, test acc:0.4459 ===
# train loss:1.4529563233170262
# train loss:1.4980741082734097
# train loss:1.6212440149787322
# === epoch:189, train acc:0.5733333333333334, test acc:0.4449 ===
# train loss:1.5402534183846235
# train loss:1.5757790107862746
# train loss:1.498436405203971
# === epoch:190, train acc:0.5833333333333334, test acc:0.4476 ===
# train loss:1.548122727787518
# train loss:1.450665095067846
# train loss:1.4183338706284099
# === epoch:191, train acc:0.5933333333333334, test acc:0.4538 ===
# train loss:1.4718063445432847
# train loss:1.4452240354262824
# train loss:1.5592598078427815
# === epoch:192, train acc:0.6, test acc:0.4584 ===
# train loss:1.5082402465136238
# train loss:1.4672037256516335
# train loss:1.4410839797675814
# === epoch:193, train acc:0.59, test acc:0.458 ===
# train loss:1.5168037610015583
# train loss:1.4321005790890555
# train loss:1.4573362923691804
# === epoch:194, train acc:0.5966666666666667, test acc:0.4625 ===
# train loss:1.4829743363776424
# train loss:1.3063319297536853
# train loss:1.3716710206115317
# === epoch:195, train acc:0.59, test acc:0.461 ===
# train loss:1.3604198446891769
# train loss:1.3899828466147277
# train loss:1.4476910995917422
# === epoch:196, train acc:0.5933333333333334, test acc:0.4611 ===
# train loss:1.462197049379945
# train loss:1.538767298350023
# train loss:1.480211958045703
# === epoch:197, train acc:0.5933333333333334, test acc:0.4602 ===
# train loss:1.351823321590434
# train loss:1.4260661003562596
# train loss:1.4474949414095073
# === epoch:198, train acc:0.6, test acc:0.4656 ===
# train loss:1.41659083247161
# train loss:1.366733998793595
# train loss:1.4807759461961583
# === epoch:199, train acc:0.5833333333333334, test acc:0.4584 ===
# train loss:1.5765520552637973
# train loss:1.388836479476191
# train loss:1.4421360236864418
# === epoch:200, train acc:0.5966666666666667, test acc:0.4654 ===
# train loss:1.4236343788100012
# train loss:1.3379156014968578
# train loss:1.4783330136477144
# === epoch:201, train acc:0.6, test acc:0.4667 ===
# train loss:1.3750960699228116
# train loss:1.482039797485651
# train loss:1.3342415487770416
# === epoch:202, train acc:0.6066666666666667, test acc:0.4726 ===
# train loss:1.3443853140306112
# train loss:1.277834937718092
# train loss:1.2642828999919125
# === epoch:203, train acc:0.6033333333333334, test acc:0.4718 ===
# train loss:1.3396858117423962
# train loss:1.4270831449587282
# train loss:1.2745731425606326
# === epoch:204, train acc:0.61, test acc:0.4835 ===
# train loss:1.3724794473342994
# train loss:1.225222693218087
# train loss:1.5237321783651683
# === epoch:205, train acc:0.6166666666666667, test acc:0.4884 ===
# train loss:1.374595768491731
# train loss:1.4967544480248405
# train loss:1.3280625984055872
# === epoch:206, train acc:0.6166666666666667, test acc:0.4898 ===
# train loss:1.3408531698237893
# train loss:1.367875230019311
# train loss:1.282534475348213
# === epoch:207, train acc:0.6166666666666667, test acc:0.4898 ===
# train loss:1.2935454802947997
# train loss:1.1655371112446793
# train loss:1.262611630677689
# === epoch:208, train acc:0.6066666666666667, test acc:0.486 ===
# train loss:1.4031408676658481
# train loss:1.2483381280998977
# train loss:1.3522536335236572
# === epoch:209, train acc:0.6133333333333333, test acc:0.4951 ===
# train loss:1.196235563146566
# train loss:1.3748368061636065
# train loss:1.3773056564178197
# === epoch:210, train acc:0.6066666666666667, test acc:0.4888 ===
# train loss:1.3654414493022657
# train loss:1.3460653040923483
# train loss:1.25834677359845
# === epoch:211, train acc:0.6033333333333334, test acc:0.4885 ===
# train loss:1.2523355359461912
# train loss:1.4241105154491551
# train loss:1.2215590325204884
# === epoch:212, train acc:0.6033333333333334, test acc:0.4801 ===
# train loss:1.374975211282547
# train loss:1.25457172492776
# train loss:1.3457148349437558
# === epoch:213, train acc:0.6033333333333334, test acc:0.4791 ===
# train loss:1.254016552969615
# train loss:1.336099128487704
# train loss:1.2207932669165331
# === epoch:214, train acc:0.6066666666666667, test acc:0.4767 ===
# train loss:1.282725648437998
# train loss:1.369761205465557
# train loss:1.246264581259573
# === epoch:215, train acc:0.6033333333333334, test acc:0.4793 ===
# train loss:1.1414659258565252
# train loss:1.3398019952263958
# train loss:1.1892728510853763
# === epoch:216, train acc:0.6033333333333334, test acc:0.4793 ===
# train loss:1.1521160150239285
# train loss:1.2990202651341038
# train loss:1.111222848186606
# === epoch:217, train acc:0.6, test acc:0.4768 ===
# train loss:1.274442682216153
# train loss:1.299421635796522
# train loss:1.235769966490828
# === epoch:218, train acc:0.6033333333333334, test acc:0.4796 ===
# train loss:1.1883313638377364
# train loss:1.1731783592984513
# train loss:1.2528806631517921
# === epoch:219, train acc:0.5933333333333334, test acc:0.4787 ===
# train loss:1.303000454901117
# train loss:1.121398685960635
# train loss:1.1269533002229257
# === epoch:220, train acc:0.6133333333333333, test acc:0.4835 ===
# train loss:1.292273823688643
# train loss:1.141042614613685
# train loss:1.2730878655495927
# === epoch:221, train acc:0.6166666666666667, test acc:0.4962 ===
# train loss:1.2853789814452006
# train loss:1.238221932821147
# train loss:1.2519062050459078
# === epoch:222, train acc:0.63, test acc:0.5089 ===
# train loss:1.0936516726800836
# train loss:1.0682681915784764
# train loss:1.3054627076092062
# === epoch:223, train acc:0.63, test acc:0.5088 ===
# train loss:1.1958462935675502
# train loss:1.234774887778351
# train loss:1.1590300676431475
# === epoch:224, train acc:0.62, test acc:0.505 ===
# train loss:1.097901469141485
# train loss:1.1389438640475136
# train loss:1.2220414099701438
# === epoch:225, train acc:0.62, test acc:0.4995 ===
# train loss:1.1067057955999264
# train loss:1.279008369214112
# train loss:1.0750091130159185
# === epoch:226, train acc:0.6266666666666667, test acc:0.4972 ===
# train loss:1.1111544904169877
# train loss:1.1084959742159783
# train loss:1.3218333135101437
# === epoch:227, train acc:0.6233333333333333, test acc:0.503 ===
# train loss:1.221808691661537
# train loss:1.1858953496396258
# train loss:1.1511469202053954
# === epoch:228, train acc:0.6233333333333333, test acc:0.5116 ===
# train loss:1.2242513235364945
# train loss:1.1342385652402462
# train loss:1.14831324638736
# === epoch:229, train acc:0.63, test acc:0.5216 ===
# train loss:1.121207249432114
# train loss:1.1503963628706504
# train loss:1.1625893885780583
# === epoch:230, train acc:0.6466666666666666, test acc:0.5287 ===
# train loss:1.2518339498208906
# train loss:1.169103751388502
# train loss:1.28016997604102
# === epoch:231, train acc:0.66, test acc:0.5366 ===
# train loss:1.2004326394032474
# train loss:1.072933400582553
# train loss:1.1330755242853023
# === epoch:232, train acc:0.65, test acc:0.5358 ===
# train loss:1.1327534358579152
# train loss:1.2701193935469635
# train loss:1.1003763068463466
# === epoch:233, train acc:0.6433333333333333, test acc:0.5324 ===
# train loss:1.0673109750956464
# train loss:1.0845844672439309
# train loss:1.1988738076501406
# === epoch:234, train acc:0.65, test acc:0.531 ===
# train loss:1.2225007363414802
# train loss:1.2004123441524015
# train loss:1.2857906351942996
# === epoch:235, train acc:0.6566666666666666, test acc:0.5315 ===
# train loss:1.0585651930650923
# train loss:1.0512029205171236
# train loss:1.1536689037195176
# === epoch:236, train acc:0.65, test acc:0.5284 ===
# train loss:1.2016431960592227
# train loss:1.0415244833888861
# train loss:1.05207314608591
# === epoch:237, train acc:0.6533333333333333, test acc:0.535 ===
# train loss:0.9954749013407649
# train loss:1.1009824102531491
# train loss:1.09042957116352
# === epoch:238, train acc:0.6566666666666666, test acc:0.5379 ===
# train loss:0.9994620092847828
# train loss:0.9739139785487518
# train loss:0.8880422799624008
# === epoch:239, train acc:0.6566666666666666, test acc:0.5372 ===
# train loss:1.0044380186528508
# train loss:1.124422488301696
# train loss:0.9807621321347313
# === epoch:240, train acc:0.66, test acc:0.5383 ===
# train loss:1.051092945305127
# train loss:1.0136805196821133
# train loss:1.0903750759503517
# === epoch:241, train acc:0.6566666666666666, test acc:0.5373 ===
# train loss:1.1570646506408044
# train loss:1.0518097144005845
# train loss:1.0813957767252378
# === epoch:242, train acc:0.65, test acc:0.5403 ===
# train loss:1.1005554962687918
# train loss:0.9418796605251759
# train loss:0.882878045273505
# === epoch:243, train acc:0.6533333333333333, test acc:0.5414 ===
# train loss:1.1233320643759739
# train loss:1.0767552630039707
# train loss:0.9459391911215479
# === epoch:244, train acc:0.65, test acc:0.5423 ===
# train loss:0.9838806584131148
# train loss:1.0795725307539452
# train loss:1.0012154794419783
# === epoch:245, train acc:0.6533333333333333, test acc:0.5437 ===
# train loss:0.9823603274684551
# train loss:1.0611482386582598
# train loss:1.022372177356023
# === epoch:246, train acc:0.6533333333333333, test acc:0.5477 ===
# train loss:1.0465230164829602
# train loss:1.0861190206662095
# train loss:1.0110216127513207
# === epoch:247, train acc:0.66, test acc:0.5579 ===
# train loss:1.0558601021419465
# train loss:0.9909669653518511
# train loss:0.9977599852391701
# === epoch:248, train acc:0.6666666666666666, test acc:0.5567 ===
# train loss:0.9225273278083804
# train loss:0.8689905328963089
# train loss:1.014015864258981
# === epoch:249, train acc:0.6566666666666666, test acc:0.5506 ===
# train loss:1.0239321608469103
# train loss:1.1301621946269578
# train loss:1.0604213627172252
# === epoch:250, train acc:0.6533333333333333, test acc:0.5534 ===
# train loss:0.9746166478881054
# train loss:0.9601440170409138
# train loss:1.0154956267133215
# === epoch:251, train acc:0.6566666666666666, test acc:0.5579 ===
# train loss:1.083176507184668
# train loss:1.0204399518299427
# train loss:1.0862825163471428
# === epoch:252, train acc:0.6766666666666666, test acc:0.5587 ===
# train loss:1.0483051992286903
# train loss:0.9359354560473859
# train loss:1.0860967635896743
# === epoch:253, train acc:0.67, test acc:0.5527 ===
# train loss:1.016538694799723
# train loss:0.985894270065359
# train loss:1.0730888490620747
# === epoch:254, train acc:0.6666666666666666, test acc:0.5534 ===
# train loss:0.9089974931327525
# train loss:1.0753102271404382
# train loss:1.1126965682195062
# === epoch:255, train acc:0.69, test acc:0.558 ===
# train loss:0.9725512916792342
# train loss:0.916165798542196
# train loss:0.991586379595234
# === epoch:256, train acc:0.6966666666666667, test acc:0.5599 ===
# train loss:1.026388427395749
# train loss:0.9037475681451019
# train loss:0.9845368559592775
# === epoch:257, train acc:0.6966666666666667, test acc:0.5646 ===
# train loss:0.9336883139687313
# train loss:1.0397002171185379
# train loss:0.9844940036653638
# === epoch:258, train acc:0.71, test acc:0.5779 ===
# train loss:0.9663287088335071
# train loss:0.992113421415219
# train loss:0.9657701678232677
# === epoch:259, train acc:0.71, test acc:0.5776 ===
# train loss:1.0215646218375192
# train loss:0.9512961019222927
# train loss:1.025632006415204
# === epoch:260, train acc:0.7033333333333334, test acc:0.5779 ===
# train loss:1.0191375422504132
# train loss:0.8984480424502184
# train loss:1.00949727661262
# === epoch:261, train acc:0.7133333333333334, test acc:0.5759 ===
# train loss:0.8564643035801489
# train loss:1.1430530746037861
# train loss:1.092987193075141
# === epoch:262, train acc:0.7, test acc:0.5695 ===
# train loss:1.0153771944381103
# train loss:0.8114310217450312
# train loss:0.8647821019603309
# === epoch:263, train acc:0.6933333333333334, test acc:0.5689 ===
# train loss:1.0844176746506102
# train loss:0.955443605224752
# train loss:0.8471224123923007
# === epoch:264, train acc:0.7, test acc:0.5758 ===
# train loss:0.9123691517111108
# train loss:0.9895553094271624
# train loss:0.9900020581856893
# === epoch:265, train acc:0.7033333333333334, test acc:0.5803 ===
# train loss:1.0601215700739202
# train loss:0.9083852971911073
# train loss:0.9493357009876404
# === epoch:266, train acc:0.73, test acc:0.5868 ===
# train loss:0.957399301375075
# train loss:1.028425314116248
# train loss:0.8547803380205015
# === epoch:267, train acc:0.7233333333333334, test acc:0.5896 ===
# train loss:0.9381011020791198
# train loss:1.0287840678977813
# train loss:0.9406885893949518
# === epoch:268, train acc:0.7233333333333334, test acc:0.5923 ===
# train loss:0.7890109582462145
# train loss:0.9222312071926331
# train loss:0.7805115707704456
# === epoch:269, train acc:0.73, test acc:0.5929 ===
# train loss:0.7542523811379247
# train loss:0.7842516230519962
# train loss:1.0440643490221437
# === epoch:270, train acc:0.73, test acc:0.592 ===
# train loss:0.9430963929916593
# train loss:0.9209665047920429
# train loss:0.833888396783355
# === epoch:271, train acc:0.73, test acc:0.5871 ===
# train loss:0.8567920920649796
# train loss:1.1911185389888095
# train loss:0.8949301098604824
# === epoch:272, train acc:0.73, test acc:0.5953 ===
# train loss:0.9393052631494136
# train loss:0.8642564035005413
# train loss:0.8231148103072686
# === epoch:273, train acc:0.7366666666666667, test acc:0.5979 ===
# train loss:0.9374223361003412
# train loss:0.8476912092432086
# train loss:1.07020529164027
# === epoch:274, train acc:0.7333333333333333, test acc:0.5995 ===
# train loss:0.9993081047813556
# train loss:0.8264102109377828
# train loss:0.869375336129094
# === epoch:275, train acc:0.73, test acc:0.5989 ===
# train loss:0.939930852488986
# train loss:0.815367077421716
# train loss:0.9342198252383332
# === epoch:276, train acc:0.7333333333333333, test acc:0.6009 ===
# train loss:0.8772697892358987
# train loss:0.8714677471577399
# train loss:0.8885556308583071
# === epoch:277, train acc:0.7366666666666667, test acc:0.6008 ===
# train loss:0.8803243950339992
# train loss:0.7601778120609421
# train loss:0.764352372362647
# === epoch:278, train acc:0.74, test acc:0.5975 ===
# train loss:0.8667030483740922
# train loss:0.8831803122464534
# train loss:0.8339463027863956
# === epoch:279, train acc:0.7533333333333333, test acc:0.6019 ===
# train loss:0.7969442359538419
# train loss:0.7602487962808959
# train loss:0.8799515209379004
# === epoch:280, train acc:0.7533333333333333, test acc:0.6018 ===
# train loss:1.0108720023680713
# train loss:0.769026796951156
# train loss:0.794016946863724
# === epoch:281, train acc:0.7533333333333333, test acc:0.6067 ===
# train loss:0.934454215268497
# train loss:0.7642324685750397
# train loss:0.9362255449646171
# === epoch:282, train acc:0.75, test acc:0.6142 ===
# train loss:0.8317937144170062
# train loss:0.7480808974599031
# train loss:0.8221863883548423
# === epoch:283, train acc:0.75, test acc:0.6064 ===
# train loss:0.7412909110196096
# train loss:0.9027951332373854
# train loss:0.8680678648091953
# === epoch:284, train acc:0.73, test acc:0.6024 ===
# train loss:0.7547253524420701
# train loss:0.8172405544722033
# train loss:0.9207664670589313
# === epoch:285, train acc:0.7266666666666667, test acc:0.5998 ===
# train loss:0.8633450221987625
# train loss:0.786976691485723
# train loss:0.7594933373565677
# === epoch:286, train acc:0.7266666666666667, test acc:0.6005 ===
# train loss:0.7788559111074234
# train loss:0.6936926578518338
# train loss:0.7531628197157412
# === epoch:287, train acc:0.74, test acc:0.6066 ===
# train loss:0.8723251411969768
# train loss:0.872638875759456
# train loss:0.8820640622747363
# === epoch:288, train acc:0.7266666666666667, test acc:0.6051 ===
# train loss:0.8502005025623215
# train loss:0.8134156496112307
# train loss:0.9780772528045695
# === epoch:289, train acc:0.7366666666666667, test acc:0.6076 ===
# train loss:0.6852214620476035
# train loss:0.8863673934429178
# train loss:0.806756757964016
# === epoch:290, train acc:0.7466666666666667, test acc:0.6168 ===
# train loss:0.7958610296836583
# train loss:0.8149446089357862
# train loss:0.7454604024587457
# === epoch:291, train acc:0.7466666666666667, test acc:0.6206 ===
# train loss:0.7283937601859998
# train loss:0.8521026080066487
# train loss:0.7878331258062548
# === epoch:292, train acc:0.7466666666666667, test acc:0.6217 ===
# train loss:0.9082913870581699
# train loss:0.8445139535447074
# train loss:0.745571999771304
# === epoch:293, train acc:0.7466666666666667, test acc:0.6228 ===
# train loss:0.8330529816706432
# train loss:0.7863842589686867
# train loss:0.8028178208553889
# === epoch:294, train acc:0.7533333333333333, test acc:0.6254 ===
# train loss:0.801360958906167
# train loss:0.719923121903025
# train loss:0.8589170552981662
# === epoch:295, train acc:0.7533333333333333, test acc:0.6258 ===
# train loss:0.6840714652000998
# train loss:0.7365632676780173
# train loss:0.7933166946532372
# === epoch:296, train acc:0.7533333333333333, test acc:0.6216 ===
# train loss:0.8181328661910408
# train loss:0.5964573898896766
# train loss:0.7810473776950075
# === epoch:297, train acc:0.7566666666666667, test acc:0.6216 ===
# train loss:0.6971884820038055
# train loss:0.708836072526205
# train loss:0.695719089721209
# === epoch:298, train acc:0.7533333333333333, test acc:0.6216 ===
# train loss:0.6974947305429943
# train loss:0.802906763716675
# train loss:0.8747741802542623
# === epoch:299, train acc:0.76, test acc:0.6154 ===
# train loss:0.6470683968511513
# train loss:0.8414292451094674
# train loss:0.8143144274162009
# === epoch:300, train acc:0.7466666666666667, test acc:0.6178 ===
# train loss:0.8375130527960328
# train loss:0.925019244775836
# train loss:0.7256208782946559
# === epoch:301, train acc:0.7433333333333333, test acc:0.6207 ===
# train loss:0.8328637120054396
# train loss:0.7250258925828045
# =============== Final Test Accuracy ===============
# test acc:0.6233

# %%
import os
import sys
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
from common.util import shuffle_dataset
(x_train, t_train), (x_test, t_test) = load_mnist()

x_train, t_train = shuffle_dataset(x_train, t_train)

validation_rate = 0.2
validation_num = int(x_train.shape[0] * validation_rate)

x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]

# %%
weight_decay = 10 ** np.random.uniform(-8, -4)
lr = 10 ** np.random.uniform(-6, -2)

# %%
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.util import shuffle_dataset
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 결과를 빠르게 얻기 위해 훈련 데이터를 줄임
x_train = x_train[:500]
t_train = t_train[:500]

# 20%를 검증 데이터로 분할
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]


def __train(lr, weight_decay, epocs=50):
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list


# 하이퍼파라미터 무작위 탐색======================================
optimization_trial = 100
results_val = {}
results_train = {}
for _ in range(optimization_trial):
    # 탐색한 하이퍼파라미터의 범위 지정===============
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list

# 그래프 그리기========================================================
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()
# Out:
# val acc:0.15 | lr:5.839590283665866e-05, weight decay:2.4188869355482196e-07
# val acc:0.13 | lr:3.198212175428862e-05, weight decay:1.6857176417541733e-06
# val acc:0.12 | lr:0.0002463467699810075, weight decay:2.8564071129820805e-07
# val acc:0.1 | lr:2.0146589465834803e-05, weight decay:3.3912180402894625e-06
# val acc:0.14 | lr:2.7360017064725895e-06, weight decay:7.159571183530086e-05
# val acc:0.09 | lr:3.196572825479774e-06, weight decay:1.457178918502026e-07
# val acc:0.3 | lr:0.0023161182637645105, weight decay:6.79949254997653e-06
# val acc:0.38 | lr:0.0033107014478472438, weight decay:2.5717309144236612e-05
# val acc:0.12 | lr:3.174221820084514e-05, weight decay:1.1877496378749995e-05
# val acc:0.13 | lr:2.5688168538771097e-06, weight decay:1.612703101841546e-05
# val acc:0.06 | lr:0.0003042669098531804, weight decay:1.7215028263330763e-06
# val acc:0.12 | lr:3.2255610952169494e-06, weight decay:4.0464985376204654e-05
# val acc:0.09 | lr:1.7410272947884686e-05, weight decay:3.141663306398141e-06
# val acc:0.1 | lr:2.4937250131550467e-05, weight decay:7.936138480048541e-08
# val acc:0.27 | lr:0.0005816101967362775, weight decay:2.20027898749035e-05
# val acc:0.14 | lr:1.7445651170883318e-06, weight decay:1.1291426180906375e-07
# val acc:0.09 | lr:3.7693582782387107e-05, weight decay:1.1330417478010088e-07
# val acc:0.37 | lr:0.002169892248288178, weight decay:6.8310734540454155e-06
# val acc:0.09 | lr:5.4821563751338105e-06, weight decay:1.2595013929905347e-07
# val acc:0.06 | lr:0.000178237023833675, weight decay:1.532742043783228e-08
# val acc:0.08 | lr:2.5211049983283375e-06, weight decay:1.4847242150499069e-08
# val acc:0.08 | lr:1.2755594283086674e-05, weight decay:1.1049094811093215e-07
# val acc:0.09 | lr:2.8552431761275197e-06, weight decay:1.4976330785483911e-07
# val acc:0.06 | lr:1.8711220283782631e-06, weight decay:1.8830643338990254e-06
# val acc:0.2 | lr:0.0012975891504116968, weight decay:7.640303199198299e-08
# val acc:0.19 | lr:0.001190589349072047, weight decay:4.246615654167515e-08
# val acc:0.11 | lr:1.6444213603188292e-06, weight decay:3.241475890130155e-06
# val acc:0.15 | lr:0.0005577299388874181, weight decay:4.8649529283339157e-05
# val acc:0.42 | lr:0.0038990133500594474, weight decay:3.123388917158502e-05
# val acc:0.72 | lr:0.006388989367607236, weight decay:4.788718406054073e-07
# val acc:0.12 | lr:0.0003674442580784206, weight decay:9.377477489136866e-05
# val acc:0.16 | lr:8.405893008148439e-05, weight decay:7.633062043982618e-07
# val acc:0.12 | lr:7.729422534388454e-06, weight decay:7.849331571421579e-08
# val acc:0.08 | lr:0.00010120087213244125, weight decay:3.946814925739371e-08
# val acc:0.08 | lr:2.46026055940394e-05, weight decay:1.127438512886957e-08
# val acc:0.17 | lr:2.049499976228878e-05, weight decay:3.073636752196315e-06
# val acc:0.15 | lr:3.063082978447766e-05, weight decay:1.2588610756078554e-08
# val acc:0.27 | lr:0.0011785482020938804, weight decay:1.983546322557404e-05
# val acc:0.04 | lr:2.663438498078212e-05, weight decay:1.1933966371838173e-08
# val acc:0.04 | lr:1.0014400720842935e-06, weight decay:1.2893594092790245e-08
# val acc:0.55 | lr:0.004119682273974986, weight decay:2.594777678825824e-06
# val acc:0.09 | lr:1.4381346702232423e-06, weight decay:5.574463480387561e-07
# val acc:0.09 | lr:2.0120158873330543e-06, weight decay:2.291941670530414e-06
# val acc:0.09 | lr:1.7230219853721626e-05, weight decay:1.7691690258374322e-07
# val acc:0.11 | lr:0.00012626291089161325, weight decay:3.7113318955576165e-07
# val acc:0.23 | lr:0.0009335936947579859, weight decay:9.666298384507433e-08
# val acc:0.13 | lr:0.0007817539438348668, weight decay:1.0202814692632495e-08
# val acc:0.11 | lr:5.275567006202658e-06, weight decay:2.9245122870641205e-08
# val acc:0.18 | lr:0.0014886304319114284, weight decay:1.585741404933226e-06
# val acc:0.09 | lr:0.00021593105705278122, weight decay:1.206854431870452e-05
# val acc:0.49 | lr:0.0031459293548196164, weight decay:7.634061043591728e-07
# val acc:0.43 | lr:0.0027879350978569964, weight decay:5.673765459429042e-05
# val acc:0.16 | lr:3.1561106961164344e-06, weight decay:2.2306626533885382e-08
# val acc:0.16 | lr:0.0005729612961697354, weight decay:9.596120265056253e-08
# val acc:0.18 | lr:3.825396138381564e-05, weight decay:1.8023763765886324e-08
# val acc:0.1 | lr:2.530137710878131e-05, weight decay:3.801557796830357e-06
# val acc:0.14 | lr:0.00033289681275059876, weight decay:1.5840627297594675e-06
# val acc:0.1 | lr:1.7451278284302698e-06, weight decay:9.272130432024968e-07
# val acc:0.18 | lr:0.0008850456568780852, weight decay:1.850198375808618e-06
# val acc:0.51 | lr:0.004056137918750534, weight decay:1.9131539011532407e-06
# val acc:0.3 | lr:0.0011083982309202142, weight decay:1.5227631238397241e-05
# val acc:0.1 | lr:5.0608849103948146e-06, weight decay:1.3512951464585893e-08
# val acc:0.11 | lr:1.1461916352304997e-05, weight decay:5.587855663525179e-06
# val acc:0.09 | lr:5.8857245690018625e-06, weight decay:5.49698570723726e-05
# val acc:0.24 | lr:0.0018184092104326602, weight decay:1.9288721574803943e-06
# val acc:0.24 | lr:0.0006812432647173349, weight decay:1.087436191714264e-08
# val acc:0.07 | lr:1.4699275958724111e-05, weight decay:2.1043799026659868e-08
# val acc:0.06 | lr:0.00017012251206968815, weight decay:2.455917887497749e-08
# val acc:0.08 | lr:1.4773136800572218e-06, weight decay:2.2299987300025895e-06
# val acc:0.09 | lr:4.598968689319994e-05, weight decay:2.117036774558159e-07
# val acc:0.14 | lr:3.852546443553666e-06, weight decay:1.7201034874448407e-08
# val acc:0.19 | lr:0.0015355607833199274, weight decay:1.5584079770493454e-06
# val acc:0.1 | lr:2.1168815486006446e-06, weight decay:5.198188644805811e-06
# val acc:0.1 | lr:3.4589867945148207e-06, weight decay:7.520615883945361e-06
# val acc:0.14 | lr:0.00028003118342024473, weight decay:3.1780975418168608e-06
# val acc:0.11 | lr:1.36172569925259e-05, weight decay:3.952934601855631e-05
# val acc:0.2 | lr:0.001271458464533202, weight decay:1.5555028104300105e-08
# val acc:0.14 | lr:9.03572821076947e-05, weight decay:2.6738463407654656e-07
# val acc:0.39 | lr:0.0025848767323242983, weight decay:1.4845542295526515e-08
# val acc:0.15 | lr:0.0006648831774591305, weight decay:2.2471275471143987e-06
# val acc:0.49 | lr:0.0030118496071029318, weight decay:2.578089569544182e-07
# val acc:0.12 | lr:0.0004238894674012657, weight decay:1.0780111531987436e-07
# val acc:0.08 | lr:7.404824888436159e-06, weight decay:1.5089294313424996e-08
# val acc:0.62 | lr:0.003967470312548895, weight decay:2.6457612057885116e-08
# val acc:0.1 | lr:6.3534074348814755e-06, weight decay:8.87939462550444e-06
# val acc:0.24 | lr:0.0018893132974771056, weight decay:1.2283232751048367e-05
# val acc:0.1 | lr:0.0003685364987269235, weight decay:4.102778101017058e-08
# val acc:0.09 | lr:2.0945091933426996e-06, weight decay:1.3429739630703195e-05
# val acc:0.11 | lr:6.688153246176774e-05, weight decay:5.119858698745585e-05
# val acc:0.1 | lr:0.00010547650724082044, weight decay:1.5203330989443375e-05
# val acc:0.07 | lr:2.089293859577316e-06, weight decay:3.218179214722298e-05
# val acc:0.05 | lr:8.143428739431418e-05, weight decay:2.0553142631416354e-08
# val acc:0.14 | lr:0.00013339657941515795, weight decay:3.634620819186583e-07
# val acc:0.15 | lr:2.0463622115134683e-05, weight decay:3.2272947883607094e-05
# val acc:0.51 | lr:0.003575194800011105, weight decay:9.164079043301956e-05
# val acc:0.18 | lr:0.0008633983383222114, weight decay:1.5661271370612055e-05
# val acc:0.16 | lr:3.2688504601158956e-05, weight decay:6.005783336809897e-06
# val acc:0.36 | lr:0.002685658707376853, weight decay:1.4425790601563442e-05
# val acc:0.1 | lr:3.11431684766381e-05, weight decay:1.067492783119811e-06
# val acc:0.06 | lr:3.5446858253163965e-05, weight decay:6.258546314025976e-05
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.72) | lr:0.006388989367607236, weight decay:4.788718406054073e-07
# Best-2(val acc:0.62) | lr:0.003967470312548895, weight decay:2.6457612057885116e-08
# Best-3(val acc:0.55) | lr:0.004119682273974986, weight decay:2.594777678825824e-06
# Best-4(val acc:0.51) | lr:0.004056137918750534, weight decay:1.9131539011532407e-06
# Best-5(val acc:0.51) | lr:0.003575194800011105, weight decay:9.164079043301956e-05
# Best-6(val acc:0.49) | lr:0.0031459293548196164, weight decay:7.634061043591728e-07
# Best-7(val acc:0.49) | lr:0.0030118496071029318, weight decay:2.578089569544182e-07
# Best-8(val acc:0.43) | lr:0.0027879350978569964, weight decay:5.673765459429042e-05
# Best-9(val acc:0.42) | lr:0.0038990133500594474, weight decay:3.123388917158502e-05
# Best-10(val acc:0.39) | lr:0.0025848767323242983, weight decay:1.4845542295526515e-08
# Best-11(val acc:0.38) | lr:0.0033107014478472438, weight decay:2.5717309144236612e-05
# Best-12(val acc:0.37) | lr:0.002169892248288178, weight decay:6.8310734540454155e-06
# Best-13(val acc:0.36) | lr:0.002685658707376853, weight decay:1.4425790601563442e-05
# Best-14(val acc:0.3) | lr:0.0023161182637645105, weight decay:6.79949254997653e-06
# Best-15(val acc:0.3) | lr:0.0011083982309202142, weight decay:1.5227631238397241e-05
# Best-16(val acc:0.27) | lr:0.0005816101967362775, weight decay:2.20027898749035e-05
# Best-17(val acc:0.27) | lr:0.0011785482020938804, weight decay:1.983546322557404e-05
# Best-18(val acc:0.24) | lr:0.0018184092104326602, weight decay:1.9288721574803943e-06
# Best-19(val acc:0.24) | lr:0.0006812432647173349, weight decay:1.087436191714264e-08
# Best-20(val acc:0.24) | lr:0.0018893132974771056, weight decay:1.2283232751048367e-05
